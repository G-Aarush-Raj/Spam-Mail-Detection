# %% [markdown]
# <a href="https://colab.research.google.com/github/G-Aarush-Raj/Spam-Mail-Detection/blob/main/SpamMailDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pgmpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Required Libraries**

# %%
#Libraries required for the project
import pandas as pd #for reading the dataset(csv) file to implement the code
from pgmpy.models import BayesianModel #from pgmpy importing the naive bayes model
from pgmpy.estimators import MaximumLikelihoodEstimator #importing the maxLikelyhood Estimater
from pgmpy.inference import VariableElimination #importing the VariableElimination module

# %% [markdown]
# **Data Loading and Preprocessing**

# %%
data=pd.read_csv("ai_spam_dataset_500.csv") #using pandas we read the dataset
Spam_or_Ham=pd.DataFrame(data) #converting the dataset to a data frame

# %%
data.head() #the first four values of the dataset to know the format
# Out:
#    sno  frequency_of_words  spam
# 0    1                 155     1
# 1    2                 136     1
# 2    3                 138     1
# 3    4                  96     0
# 4    5                  18     0

# %%
print(Spam_or_Ham) #Printing the data frame that is being loaded to the model
# Out:
#      sno  frequency_of_words  spam
# 0      1                 155     1
# 1      2                 136     1
# 2      3                 138     1
# 3      4                  96     0
# 4      5                  18     0
# ..   ...                 ...   ...
# 495  496                  67     0
# 496  497                  62     0
# 497  498                  78     0
# 498  499                  91     0
# 499  500                 191     1
#
# [500 rows x 3 columns]

# %% [markdown]
# **MODEL**

# %%
naive_bayes_model = BayesianModel([('frequency_of_words','spam')])
#using the naive bayes model to find the relation and build the model
#the is a definite relation between the frequency of words and a mail being spam or ham
# Out:
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.

# %%
naive_bayes_model.fit(Spam_or_Ham, estimator=MaximumLikelihoodEstimator) #Using the model.fit() to train the model with dataframe
Bayes_SMD = VariableElimination(naive_bayes_model)# the VariableElimination model is used to perform inference

# %% [markdown]
# **MODEL TESTING**

# %%
def Count(m):#this method is used to count the frequency words
  d={"the":0,"of":0,"a":0,"an":0,"by":0,"to":0,"ect":0,"and":0,"for":0,"you":0,"at":0}
  for i in m.split():
    if i.lower() in d:
      d[i.lower()]+=1
  s=0
  for i in d:
    s+=d[i]
  return s

# %%
def TestTheModel(): #this method is used to test the model with a mail data to check whether it is spam or ham
  mail_data = input()
  value = Count(mail_data)
  q = Bayes_SMD.query(variables=['spam'],evidence={'frequency_of_words': int(value)})
  print("===========================")
  print("===========================")
  if q.values[1]==1:
    print(" It is a Spam Mail ")
  else:
    print(" It is a Ham Mail ")
  print("============================")
  print("============================")

TestTheModel() #Final function call
# Out:
# Subject: The Opportunity of a Lifetime to Transform Your Future  Body: Dear Recipient,  Have you ever wondered about the secret of achieving the life of your dreams? The time has come to uncover the potential of a revolutionary system that has changed the lives of thousands. This is not just another offer; this is the opportunity of a lifetime to gain control of your financial future and live a life free of worries.  The world of success is built upon the foundation of proven strategies and the expertise of individuals who understand the dynamics of wealth creation. Our program offers a step-by-step guide to unlock the potential of your income, giving you the freedom to enjoy the finer things of life.  At the heart of this program lies a series of lessons crafted by the pioneers of financial independence. Each lesson delves into the nuances of achieving a stable and growing income, making it accessible to anyone willing to take a step toward a better future.  The benefits of this pro
# ...
